# %%
import os
from pathlib import Path
import pandas as pd

from vascx.features.caliber import Caliber
from vascx.utils.analysis import get_examples_dict, make_retina
from vascx.utils.plotting import plot_grid

# %%
ds_path = "../../samples/ergo/good/"

# %%
examples = get_examples_dict(ds_path)

# %%
r = make_retina(examples[245938])

# %%
Caliber().plot(r.arteries)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# (<Figure size 1200x1200 with 1 Axes>, <Axes: >)

# %%
Caliber().compute(r.arteries)
# Out:
# {'mean': 5.1182744018977235,
#  'median': 4.553115446207935,
#  'std': 2.5745042554925424}

# %%
import numpy as np
r.veins.vessels.plot(text=lambda x: f"{np.std([d.diameter for d in x.diameters]):.2f}")
# Out:
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# /home/jose/miniconda3/lib/python3.10/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/jose/miniconda3/lib/python3.10/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/jose/miniconda3/lib/python3.10/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# (<Figure size 1200x1200 with 1 Axes>, <Axes: >)

# %%
Caliber().plot(r.veins)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# (<Figure size 1200x1200 with 1 Axes>, <Axes: >)

# %%
Caliber().compute(r.veins)
# Out:
# {'mean': 4.742895456995677,
#  'median': 3.559412313599435,
#  'std': 3.173894461861109}
