# %%
from pathlib import Path

import numpy as np
from matplotlib import pyplot as plt
from vascx.fundus.loader import RetinaLoader
from vascx.fundus.features.bifurcation_angles import BifurcationAngles
from rtnls_enface.grids.ellipse import EllipseField
from rtnls_enface.grids.circle import CircleField
from rtnls_enface.utils.plotting import plot_grid

# %%
ds_path = Path("../../samples/fundus")
loader = RetinaLoader.from_folder(ds_path)
# Out:
# Folder av_path: 6 files
# Folder disc_path: 6 files
# Folder fundus_path: 6 files
# Folder vessels_path: 6 files

# %%
feature = BifurcationAngles(grid_field=CircleField.Superior)
# def make_plot_fn(retina):
#     def plot_fn(ax):
#         try:
            
#             feature.plot(ax=ax, layer=retina.arteries)
#             value = np.mean(feature.compute(retina.arteries))
#             ax.text(10, 20, f'{value:.2f}', color='w')
#         except:
#             ax.text(10, 20, 'NA', color='w')
#             return

#     return plot_fn
def plot_fn(ax, row, col, i):
    i = 3*row+col
    r = loader[i]
    feature.plot(ax=ax, layer=r.arteries)
    # value = np.mean(feature.compute(r.arteries))
    # if isinstance(value, dict):
    #     ax.text(10, 50, str(value), color='w', fontsize='small')
    # else:
    #     ax.text(10, 50, f'{np.mean(value):.2f}', color='w', fontsize='small')

# %%
plot_grid(plot_fn, ncols=3, nrows=2)
# Out:
# (<Figure size 2400x3600 with 12 Axes>,
#  <mpl_toolkits.axes_grid1.axes_grid.ImageGrid at 0x7f89d0cf7c50>)
