# %%
from pathlib import Path

from vascx import RetinaLoader
from vascx.utils.analysis import (
    extract_in_parallel,
)

# %%
ds_path = Path("../../samples/fundus/ergo/good")

# %%
loader = RetinaLoader.from_folder(ds_path, fundus_subfolder=None)

# %%
res = extract_in_parallel(loader.to_dict(), "bergmann", n_jobs=1)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s][Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.7s remaining:    0.0s
# ...
# 100%|██████████| 16/16 [01:29<00:00,  5.60s/it]
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:  1.5min finished

# %%
res
# Out:
#     ta_arteries    ta_veins  cre_arteries  cre_veins  vd_arteries  vd_veins  \
# 0    129.818000  141.723471     10.850761  16.925067     0.056352  0.074332
# 1     80.327569  137.687344     11.102651  14.863187     0.053917  0.063940
# 2    100.583598   86.411247      9.451283  15.747613     0.036863  0.053417
# 3    148.676774  170.714250      9.534378  14.905657     0.043539  0.053295
# 4    155.880037  134.139590     11.073596  14.975314     0.056096  0.064366
# 5    140.081150  118.916767     10.716220  17.340817     0.067643  0.078416
# 6    120.524666  154.178770     12.825269  19.569082     0.052120  0.064544
# 7    119.627788  143.396765     10.591809  18.823002     0.050283  0.076184
# 8    115.579086  119.950261     11.052608  15.481055     0.057179  0.070816
# 9    120.632931  146.143717     12.203156  15.604713     0.067271  0.065206
# 10   104.415593  135.504181     10.718119  17.028718     0.047459  0.066092
# ...
