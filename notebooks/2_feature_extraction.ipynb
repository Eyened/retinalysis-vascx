# %%
from pathlib import Path

from vascx.fundus.loader import RetinaLoader
from vascx.utils.analysis import (
    extract_in_parallel,
)

# %%
ds_path = Path("../samples/fundus")

# %%
loader = RetinaLoader.from_folder(ds_path)
# Out:
# Folder av_path: 6 files
# Folder disc_path: 6 files
# Folder fundus_path: 6 files
# Folder vessels_path: 6 files

# %%
res = extract_in_parallel(loader.to_dict(), "full_v2", n_jobs=1, print_stack_trace=True)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s][Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    2.9s
#  50%|█████     | 3/6 [00:06<00:05,  1.89s/it][Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    7.6s
# 100%|██████████| 6/6 [00:11<00:00,  1.88s/it]
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   11.3s finished

# %%
res
# Out:
#               angles_arteries  angles_veins  angles_sup_arteries  \
# CHASEDB1_08L        76.126297     81.741773            76.126297
# CHASEDB1_12R        90.000000     83.088773            84.289407
# DRIVE_22            84.147124     86.469993            94.000920
# DRIVE_40            86.364547     83.103916            83.531246
# HRF_04_g            69.614873     77.471192            69.040878
# HRF_07_dr           88.994914     75.348896            86.580730
#
#               angles_sup_veins  angles_inf_arteries  angles_inf_veins  \
# CHASEDB1_08L         76.478850            82.919908         87.004697
# CHASEDB1_12R         80.489300            90.000000         83.088773
# DRIVE_22             91.799232            83.629950         83.544448
# DRIVE_40             90.000000            95.761089         73.686148
# HRF_04_g             72.349876            75.018367         81.626048
# HRF_07_dr            74.882697            88.994914         76.271629
#
#               bif_arteries  bif_veins  bif_sup_arteries  bif_sup_veins  ...  \
# CHASEDB1_08L            17         27                 8             16  ...
# CHASEDB1_12R            20         24                10             13  ...
# DRIVE_22                24         39                11             21  ...
# DRIVE_40                21         34                14             18  ...
# HRF_04_g                27         29                15             17  ...
# HRF_07_dr               36         34                20             17  ...
#
#               tort_dist_etdrs_norm_veins  tort_curv_etdrs_norm_arteries  \
# CHASEDB1_08L                    1.045701                       6.051515
# CHASEDB1_12R                    1.045512                       8.062518
# DRIVE_22                        1.137248                       7.216840
# DRIVE_40                        1.570271                       3.505042
# HRF_04_g                        1.066942                       3.842203
# HRF_07_dr                       1.045615                       4.465727
#
#               tort_curv_etdrs_norm_veins  vd_arteries  vd_veins  \
# CHASEDB1_08L                    4.725053     0.053064  0.066937
# CHASEDB1_12R                    6.265164     0.065123  0.069066
# DRIVE_22                       16.425217     0.056614  0.075311
# DRIVE_40                        6.586529     0.060027  0.076276
# HRF_04_g                        4.638404     0.045170  0.060266
# HRF_07_dr                       6.664559     0.067229  0.066630
#
#               vd_sup_arteries  vd_sup_veins  vd_inf_arteries  vd_inf_veins  \
# CHASEDB1_08L         0.046733      0.050204         0.042904      0.063211
# CHASEDB1_12R         0.054860      0.056324         0.060602      0.061283
# DRIVE_22             0.040294      0.053565         0.047306      0.057811
# DRIVE_40             0.044313      0.062393         0.051895      0.066974
# HRF_04_g             0.035942      0.046931         0.035243      0.038598
# HRF_07_dr            0.054216      0.049611         0.047646      0.055108
#
#               odfd_image
# CHASEDB1_08L  396.526005
# CHASEDB1_12R  448.639445
# DRIVE_22      381.584045
# DRIVE_40      408.840120
# HRF_04_g      283.196234
# HRF_07_dr     307.165491
#
# [6 rows x 60 columns]

# %%
res.loc['CHASEDB1_08L',:]
# Out:
# angles_arteries                   76.126297
# angles_veins                      81.741773
# angles_sup_arteries               76.126297
# angles_sup_veins                  76.478850
# angles_inf_arteries               82.919908
# angles_inf_veins                  87.004697
# bif_arteries                      17.000000
# bif_veins                         27.000000
# bif_sup_arteries                   8.000000
# bif_sup_veins                     16.000000
# bif_inf_arteries                   9.000000
# bif_inf_veins                     11.000000
# diam_arteries                      4.896477
# diam_veins                         4.857040
# diam_sup_arteries                  4.171007
# diam_sup_veins                     4.396848
# diam_inf_arteries                  6.021301
# diam_inf_veins                     6.069380
# sparsity_mean_vessels              0.054793
# sparsity_max_vessels               0.169268
# sparsity_disc_mean_vessels         0.058159
# sparsity_disc_max_vessels          0.214020
# sparsity_fovea_mean_vessels        0.053349
# sparsity_fovea_max_vessels         0.169268
# lapl_image                         7.037933
# lapl_disc_image                    8.911155
# lapl_fovea_image                   6.955609
# cre_temporal_arteries             12.403042
# cre_temporal_veins                21.605445
# cre_temporal_sup_arteries          7.710585
# cre_temporal_sup_veins            11.139406
# cre_temporal_inf_arteries         12.655233
# cre_temporal_inf_veins            19.375119
# cre_nasal_arteries                13.338037
# cre_nasal_veins                   18.550685
# cre_full_arteries                 16.390819
# cre_full_veins                    26.053377
# tort_dist_arteries                 1.012089
# tort_dist_veins                    1.012178
# tort_curv_arteries                 3.730790
# tort_curv_veins                    3.631726
# tort_dist_norm_arteries            1.017254
# tort_dist_norm_veins               1.022378
# tort_curv_norm_arteries            3.272303
# tort_curv_norm_veins               3.193637
# tort_dist_etdrs_arteries           1.009229
# tort_dist_etdrs_veins              1.016887
# tort_curv_etdrs_arteries           5.677264
# tort_curv_etdrs_veins              4.377211
# tort_dist_etdrs_norm_arteries      1.043378
# tort_dist_etdrs_norm_veins         1.045701
# tort_curv_etdrs_norm_arteries      6.051515
# tort_curv_etdrs_norm_veins         4.725053
# vd_arteries                        0.053064
# vd_veins                           0.066937
# vd_sup_arteries                    0.046733
# vd_sup_veins                       0.050204
# vd_inf_arteries                    0.042904
# vd_inf_veins                       0.063211
# odfd_image                       396.526005
# Name: CHASEDB1_08L, dtype: float64
