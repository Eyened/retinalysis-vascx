# %%
from pathlib import Path

import numpy as np
from matplotlib import pyplot as plt
from vascx.fundus import RetinaLoader
from vascx.fundus.features.bifurcation_angles import BifurcationAngles

# %%
ds_path = Path("../../samples/fundus")
loader = RetinaLoader.from_folder(ds_path)

# %%
r = loader[3]

# %%
from rtnls_enface.grids.etdrs import ETDRSGrid

# %%
dtf = r.grids[ETDRSGrid].distance_to_fovea

# %%
np.min(dtf), np.max(dtf)

# %%
r.laterality

# %%
f = r.grids[ETDRSGrid].NOM

# %%
plt.imshow(f)

# %%
m = r.bounds.make_binary_mask()

# %%
plt.imshow(m)

# %%
m[f] == f[m]

# %%
f <= m

# %%
np.all(f <= m)

# %%
from rtnls_enface.grids.etdrs import Quadrant

fig, ax = plt.subplots(1, 1)
BifurcationAngles(grid_field=Quadrant.Temporal).plot(ax, r.veins)

# %%
fig.savefig("bifurcation_angles.png", dpi=300, bbox_inches="tight")
