# %%
from pathlib import Path

from vascx import RetinaLoader
from vascx.features.length import Length
from vascx.features.tortuosity import LengthMeasure, Tortuosity

# %%
ds_path = Path("../../../samples/fundus")
loader = RetinaLoader.from_folder(ds_path, fundus_subfolder="preprocessed_rgb")

# %%
tortuosity = Tortuosity(length_measure=LengthMeasure.Skeleton)
tortuosity_splines = Tortuosity(length_measure=LengthMeasure.Splines)
feature = Length()

# %%
skl, spl = tortuosity.raw(loader[0].veins), tortuosity_splines.raw(
    loader[0].veins)

# %%
from matplotlib import pyplot as plt

plt.scatter(skl, spl)

# %%
feature.compute(loader[0].arteries)

# %%
feature.compute_with_spline(loader[0].arteries)

# %%
feature.compute(loader[0].veins)

# %%
feature.compute_with_spline(loader[0].veins)
