# %%
from pathlib import Path

from vascx import RetinaLoader
from vascx.utils.analysis import (
    extract_in_parallel,
)

# %%
ds_path = Path("../../samples/fundus")

# %%
loader = RetinaLoader.from_folder(ds_path, fundus_subfolder=None)

# %%
res = extract_in_parallel(loader.to_dict(), "bergmann", n_jobs=1)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s][Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    6.7s
#  30%|███       | 3/10 [00:16<00:35,  5.05s/it][Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:   22.2s
#  60%|██████    | 6/10 [00:32<00:21,  5.40s/it][Parallel(n_jobs=1)]: Done   7 tasks      | elapsed:   37.9s
# 100%|██████████| 10/10 [00:55<00:00,  5.53s/it]

# %%
res
# Out:
#    ta_arteries    ta_veins  cre_arteries  cre_veins  vd_arteries  vd_veins  \
# 0   131.002975  142.564879      3.222450        NaN     0.059562  0.077206
# 1    79.958553  136.873866     10.918380  16.948964     0.055780  0.065049
# 2   119.285985  143.306175           NaN        NaN     0.050713  0.075939
# 3   116.119014  120.555530     11.360194  15.667969     0.058168  0.071950
# 4   120.820395  146.164679     11.754882  15.404344     0.067628  0.064292
# 5   132.188506  122.035583           NaN        NaN     0.067294  0.081932
# 6   119.691732   95.039695     12.703704  21.471070     0.065321  0.072622
# 7   120.399950  110.085650           NaN   4.373861     0.061362  0.069434
# 8   125.066719  149.362298     12.163232  15.485759     0.064355  0.084720
# 9   122.469865  137.562292           NaN        NaN     0.043433  0.063417
#
#    diam_arteries_median  diam_arteries_std  diam_veins_median  diam_veins_std  \
# 0              3.015302           2.053882           3.001644        2.631894
# 1              2.400180           1.778538           2.198871        2.032783
# 2              3.774159           1.997499           3.148490        2.972507
# 3              2.624857           1.779090           2.949865        1.997842
# 4              2.819854           1.986490           2.834105        2.267915
# 5              3.007089           2.153517           2.408802        2.533555
# 6              2.934660           2.253862           3.113555        3.125707
# 7              3.215386           2.024102           3.228694        2.502822
# 8              2.826252           2.283433           2.819327        2.291175
# 9              2.935861           1.935308           3.000171        2.309681
#
#    tort_arteries  tort_veins  bif_arteries  bif_veins
# 0       1.081649    1.080671            25         27
# 1       1.076452    1.080895            32         34
# 2       1.079669    1.086442            12         22
# 3       1.073751    1.077678            37         44
# 4       1.082198    1.082080            29         27
# 5       1.080945    1.080975            30         48
# 6       1.096950    1.077594            19         26
# 7       1.076080    1.080886            25         33
# 8       1.119722    1.136753            43         52
# 9       1.081142    1.080069            27         38
